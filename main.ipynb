# %%
import requests
from bs4 import BeautifulSoup
import csv

def scrape_jumia_products(url):
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        return None
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Apple Watches
    product_containers = soup.find_all("div", class_="sku -gallery")
    product_data = []
    
    for product in product_containers:
        product_name = product.find('a', class_='core')['title']
        brand_name = "Apple"  # Since we are looking for Apple Watches
        price_container = product.find('div', class_='prc')
        price = price_container.find('div', class_='prc-w')['data-prc']
        discount = product.find("span", class_="tag _dsct _sm").text.strip() if product.find("span", class_="tag _dsct _sm") else "N/A"
        num_reviews = product.find("span", class_="count _2_Rng").text.strip() if product.find("span", class_="count _2_Rng") else "N/A"
        product_rating = product.find("div", class_="rev _2nrHN")["style"]
        product_rating = float(product_rating.split(':')[-1].split('%')[0]) / 20
        
        product_data.append([product_name, brand_name, price, discount, num_reviews, product_rating])
    
    return product_data

if __name__ == "__main__":
    jumia_url = "https://www.jumia.co.ke/wearable-technology/?page=1"
    product_data = scrape_jumia_products(jumia_url)
    
    if product_data:
        with open("jumia_apple_watches.csv", "w", newline="") as csvfile:
            csv_writer = csv.writer(csvfile)
            csv_writer.writerow(["Product Name", "Brand Name", "Price (Ksh)", 
            "Discount (%)", "Total Number of Reviews"
            , "Product Rating"])
            csv_writer.writerows(product_data)
print("price")
# Out:
# price

# %%
import requests
from bs4 import BeautifulSoup

def scrape_jumia_products(url):
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        return None
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Apple Watches
    product_containers = soup.find_all("div", class_="sku -gallery")
    
    for product in product_containers:
        product_name = product.find('a', class_='core')['title']
        brand_name = "Apple"  # Since we are looking for Apple Watches
        price_container = product.find('div', class_='prc')
        price = price_container.find('div', class_='prc-w')['data-prc']
        discount = product.find("span", class_="tag _dsct _sm").text.strip() if product.find("span", class_="tag _dsct _sm") else "N/A"
        num_reviews = product.find("span", class_="count _2_Rng").text.strip() if product.find("span", class_="count _2_Rng") else "N/A"
        product_rating = product.find("div", class_="rev _2nrHN")["style"]
        product_rating = float(product_rating.split(':')[-1].split('%')[0]) / 20
        
        print(f"Product: {product_name}")
        print(f"Brand: {brand_name}")
        print(f"Price: {price} Ksh")
        print(f"Discount: {discount}")
        print(f"Number of Reviews: {num_reviews}")
        print(f"Product Rating: {product_rating}")
        print("-" * 30)

if __name__ == "__main__":
    jumia_url = "https://www.jumia.co.ke/wearable-technology/?page=1"
    scrape_jumia_products(jumia_url)

# %%
import requests
from bs4 import BeautifulSoup

def scrape_ebay_products(url):
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        return None
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # eBay Product Containers
    product_containers = soup.find_all("div", class_="s-item__info")
    
    for product in product_containers:
        # Check if product name is found
        product_name_tag = product.find('h3', class_='s-item__title')
        product_name = product_name_tag.text.strip() if product_name_tag else "Apple Watch"
        
        # Check if price is found
        price_container = product.find('span', class_='s-item__price')
        price = price_container.text.strip() if price_container else "N/A"
        
        # Check if item condition is found
        item_condition_tag = product.find('span', class_='SECONDARY_INFO')
        item_condition = item_condition_tag.text.strip() if item_condition_tag else "N/A"
        
        print(f"Product: {product_name}")
        print(f"Price: {price}")
        print(f"Condition: {item_condition}")
        print("-" * 30)

if __name__ == "__main__":
    ebay_url = "https://www.ebay.com/sch/i.html?_nkw=apple+watch"
    scrape_ebay_products(ebay_url)
# Out:
# Product: Apple Watch
# Price: $20.00
# Condition: Brand New
# ------------------------------
# Product: Apple Watch
# Price: $59.31
# Condition: Brand New
# ------------------------------
# Product: Apple Watch
# Price: $89.99
# Condition: Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $114.99
# Condition: Open Box
# ------------------------------
# Product: Apple Watch
# Price: $239.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $89.99 to $104.99
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $409.99
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $124.99
# Condition: Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $204.99
# Condition: Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $189.99
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $36.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $194.99
# Condition: Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $95.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $104.99 to $109.99
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $109.99
# Condition: Open Box
# ------------------------------
# Product: Apple Watch
# Price: $141.99
# Condition: Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $284.99
# Condition: Open Box
# ------------------------------
# Product: Apple Watch
# Price: $644.99
# Condition: Excellent - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $299.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $344.99
# Condition: Excellent - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $314.99
# Condition: Excellent - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $129.99
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $174.99
# Condition: Excellent - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $494.99
# Condition: Excellent - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $84.55 to $94.55
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $94.99
# Condition: Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $100.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $112.50
# Condition: Open Box
# ------------------------------
# Product: Apple Watch
# Price: $32.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $35.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $244.99
# Condition: Excellent - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $495.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $141.99
# Condition: Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $18.50
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $124.99
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $114.99
# Condition: Open Box
# ------------------------------
# Product: Apple Watch
# Price: $52.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $159.99
# Condition: Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $294.00
# Condition: Excellent - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $109.99
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $199.99
# Condition: Brand New
# ------------------------------
# Product: Apple Watch
# Price: $80.70
# Condition: Open Box
# ------------------------------
# Product: Apple Watch
# Price: $149.99
# Condition: Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $31.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $51.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $331.00
# Condition: Open Box
# ------------------------------
# Product: Apple Watch
# Price: $144.55
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $67.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $45.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $131.99
# Condition: Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $11.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $224.00
# Condition: Very Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $80.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $109.99
# Condition: Very Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $141.99
# Condition: Very Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $189.99
# Condition: Brand New
# ------------------------------
# Product: Apple Watch
# Price: $115.00
# Condition: Parts Only
# ------------------------------
# Product: Apple Watch
# Price: $279.00
# Condition: Excellent - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $124.99
# Condition: Brand New
# ------------------------------
# Product: Apple Watch
# Price: $289.99
# Condition: Brand New
# ------------------------------
# Product: Apple Watch
# Price: $284.99
# Condition: Brand New
# ------------------------------
# Product: Apple Watch
# Price: $234.00
# Condition: Excellent - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $131.99
# Condition: Very Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $299.99
# Condition: Excellent - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $485.00
# Condition: Open Box
# ------------------------------
# Product: Apple Watch
# Price: $224.00 to $349.00
# Condition: Excellent - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $19.99 to $44.99
# Condition: Parts Only
# ------------------------------
# Product: Apple Watch
# Price: $123.50
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $189.99
# Condition: Brand New
# ------------------------------
# Product: Apple Watch
# Price: $249.95
# Condition: Brand New
# ------------------------------
# Product: Apple Watch
# Price: $559.69
# Condition: Brand New
# ------------------------------
# Product: Apple Watch
# Price: $164.99
# Condition: Good - Refurbished
# ------------------------------
# Product: Apple Watch
# Price: $140.00
# Condition: Parts Only
# ------------------------------
# Product: Apple Watch
# Price: $53.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $120.00
# Condition: Pre-Owned
# ------------------------------
# Product: Apple Watch
# Price: $295.00
# Condition: Pre-Owned
# ------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_ebay_products(url):
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        return None
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # eBay Product Containers
    product_containers = soup.find_all("div", class_="s-item__info")
    
    data = []
    
    for product in product_containers:
        # Check if product name is found
        product_name_tag = product.find('h3', class_='s-item__title')
        product_name = product_name_tag.text.strip() if product_name_tag else "Apple Watch"
        
        # Check if price is found
        price_container = product.find('span', class_='s-item__price')
        price = price_container.text.strip() if price_container else "N/A"
        
        # Check if item condition is found
        item_condition_tag = product.find('span', class_='SECONDARY_INFO')
        item_condition = item_condition_tag.text.strip() if item_condition_tag else "N/A"
        
        data.append([product_name, price, item_condition])
    
    return data

if __name__ == "__main__":
    ebay_url = "https://www.ebay.com/sch/i.html?_nkw=apple+watch"
    product_data = scrape_ebay_products(ebay_url)
    
    if product_data:
        columns = ["Product Name", "Price", "Condition"]
        df = pd.DataFrame(product_data, columns=columns)
print(df)
# Out:
#    Product Name    Price           Condition
# 0   Apple Watch   $20.00           Brand New
# 1   Apple Watch   $59.31           Brand New
# 2   Apple Watch   $89.99  Good - Refurbished
# 3   Apple Watch  $114.99            Open Box
# 4   Apple Watch  $239.00           Pre-Owned
# ..          ...      ...                 ...
# 71  Apple Watch  $559.69           Brand New
# 72  Apple Watch  $164.99  Good - Refurbished
# 73  Apple Watch  $140.00          Parts Only
# 74  Apple Watch  $120.00           Pre-Owned
# 75  Apple Watch  $295.00           Pre-Owned
#
# [76 rows x 3 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_amazon_products(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        return None
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Amazon Product Containers
    product_containers = soup.find_all("div", class_="s-result-item")
    
    data = []
    
    for product in product_containers:
        # Check if product name is found
        product_name_tag = product.find('h2', class_='a-size-mini a-spacing-none a-color-base s-line-clamp-2')
        product_name = product_name_tag.text.strip() if product_name_tag else "Apple Watch"
        
        # Check if price is found
        price_container = product.find('span', class_='a-offscreen')
        price = price_container.text.strip() if price_container else "N/A"
        
        # Check if product rating is found
        product_rating_tag = product.find('span', class_='a-icon-alt')
        product_rating = product_rating_tag.text.strip() if product_rating_tag else "N/A"
        
        data.append([product_name, price, product_rating])
    
    return data

if __name__ == "__main__":
    amazon_url = "https://www.amazon.com/s?k=apple+watch"
    product_data = scrape_amazon_products(amazon_url)
    
    if product_data:
        columns = ["Product Name", "Price", "Product Rating"]
        df = pd.DataFrame(product_data, columns=columns)
        
        # Save to Excel file
        df.to_excel("amazon_apple_watches.xlsx", index=False)
        
        print("Data has been successfully exported to amazon_apple_watches.xlsx.")
# Out:
# Failed to retrieve the page. Status code: 503

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def scrape_ebay_products(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }

    retries = 3
    for attempt in range(retries):
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            break
        elif response.status_code == 503:
            print(f"Retrying... Attempt {attempt + 1}")
            time.sleep(5)  # Add a delay before retrying
        else:
            print(f"Failed to retrieve the eBay page. Status code: {response.status_code}")
            return None

    soup = BeautifulSoup(response.text, 'html.parser')
    
    # eBay Product Containers
    product_containers = soup.find_all("div", class_="s-item__info")
    
    data = []
    
    for product in product_containers:
        # Check if product name is found
        product_name_tag = product.find('h3', class_='s-item__title')
        product_name = product_name_tag.text.strip() if product_name_tag else "Apple Watch"
        
        # Check if price is found
        price_container = product.find('span', class_='s-item__price')
        price = price_container.text.strip() if price_container else "N/A"
        
        # Check if item condition is found
        item_condition_tag = product.find('span', class_='SECONDARY_INFO')
        item_condition = item_condition_tag.text.strip() if item_condition_tag else "N/A"
        
        data.append([product_name, price, item_condition])
    
    return data

def scrape_amazon_products(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }

    retries = 3
    for attempt in range(retries):
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            break
        elif response.status_code == 503:
            print(f"Retrying... Attempt {attempt + 1}")
            time.sleep(5)  # Add a delay before retrying
        else:
            print(f"Failed to retrieve the Amazon page. Status code: {response.status_code}")
            return None

    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Amazon Product Containers
    product_containers = soup.find_all("div", class_="s-result-item")
    
    data = []
    
    for product in product_containers:
        # Check if product name is found
        product_name_tag = product.find('h2', class_='a-size-mini a-spacing-none a-color-base s-line-clamp-2')
        product_name = product_name_tag.text.strip() if product_name_tag else "Apple Watch"
        
        # Check if price is found
        price_container = product.find('span', class_='a-offscreen')
        price = price_container.text.strip() if price_container else "N/A"
        
        # Check if product rating is found
        product_rating_tag = product.find('span', class_='a-icon-alt')
        product_rating = product_rating_tag.text.strip() if product_rating_tag else "N/A"
        
        data.append([product_name, price, product_rating])
    
    return data

if __name__ == "__main__":
    ebay_url = "https://www.ebay.com/sch/i.html?_nkw=apple+watch"
    amazon_url = "https://www.amazon.com/s?k=apple+watch"
    
    ebay_data = scrape_ebay_products(ebay_url)
    amazon_data = scrape_amazon_products(amazon_url)
    
    if ebay_data and amazon_data:
        ebay_columns = ["Product Name", "Price", "Condition"]
        amazon_columns = ["Product Name", "Price", "Product Rating"]
        
        ebay_df = pd.DataFrame(ebay_data, columns=ebay_columns)
        amazon_df = pd.DataFrame(amazon_data, columns=amazon_columns)
        
        # Save to Excel files
        ebay_df.to_excel("ebay_apple_watches.xlsx", index=False)
        amazon_df.to_excel("amazon_apple_watches.xlsx", index=False)
        
        print("Data has been successfully exported to eBay and Amazon Excel files.")
# Out:
# Retrying... Attempt 1
# Retrying... Attempt 2
# Retrying... Attempt 3
