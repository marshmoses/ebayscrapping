# %%
#%pip install ebaysdk

# %%
from ebaysdk.finding import Connection as Finding
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import os
load_dotenv()

# eBay API endpoint
EBAY_API_URL = "https://api.ebay.com/buy/browse/v1/item_summary/search"

# Get OAuth token from environment variable
OAUTH_TOKEN = os.getenv("EBAY_OAUTH_TOKEN")

# function to fetch eBay data for Apple Watches
def fetch_ebay_data(query: str, limit: int = 100):
    api = Finding(appid="MosesMac-pricemon-PRD-85bb4ae7d-e6d9b5f3", config_file=None)
    response = api.execute('findItemsAdvanced', {'keywords': query, 'paginationInput': {'entriesPerPage': limit}})
    soup = BeautifulSoup(response.content, 'lxml')
    items = soup.find_all('item')
    relevant_data = []
    for item in items:
        item_info = {
            "Title": item.title.string,
            "Price": item.currentprice.string,
            "Country of Origin": item.location.string,
            "Product Link": item.viewitemurl.string
        }
        relevant_data.append(item_info)
    return relevant_data 
#arrange price in ascending order
def arrange_price_ascending(data):
    data = sorted(data, key=lambda x: float(x["Price"].replace("$", "").replace(",", "")))
    return data

#i want to print the data
print(fetch_ebay_data("apple watch", 100))#
#print 10 items of apple watch from ebay
#i want to save the data to excel file
def save_to_excel(data, filename):
    df = pd.DataFrame(data)
    df.to_excel(filename, index=False)
    print(f"Apple Watch data saved to {filename}")
#save the data to excel file
save_to_excel(fetch_ebay_data("apple watch", 100), "apple_watch_data13.xlsx")
# Out:
# [{'Title': 'Apple Watch Series 3 38mm 42mm GPS + WiFi + Cellular Pink Gold Space Gray Silver', 'Price': '89.99', 'Country of Origin': 'Inglewood,CA,USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Series-3-38mm-42mm-GPS-WiFi-Cellular-Pink-Gold-Space-Gray-Silver-/194935793906?var=0'}, {'Title': 'Apple Watch Series 4 40mm 44mm GPS + WiFi + Bluetooth Gold Gray Silver - Good', 'Price': '124.99', 'Country of Origin': 'Inglewood,CA,USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Series-4-40mm-44mm-GPS-WiFi-Bluetooth-Gold-Gray-Silver-Good-/404026180086?var=0'}, {'Title': 'Apple Watch Series 5 (GPS + Cellular) 40mm Smartwatch - Good', 'Price': '124.99', 'Country of Origin': 'Astoria,NY,USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Series-5-GPS-Cellular-40mm-Smartwatch-Good-/254993930996?var=0'}, {'Title': 'Apple Watch Ultra 2 49mm Cellular Titanium Case w/ Blue Ocean Band MREG3LL/A', 'Price': '649.0', 'Country of Origin': 'USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Ultra-2-49mm-Cellular-Titanium-Case-w-Blue-Ocean-Band-MREG3LL-A-/364544438583'}, {'Title': 'Apple Watch Series 3 38mm 42mm ALL COLORS Aluminum Case With Band GPS Cellular', 'Price': '79.99', 'Country of Origin': 'Lakewood,NJ,USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Series-3-38mm-42mm-ALL-COLORS-Aluminum-Case-Band-GPS-Cellular-/125662941144?var=0'}, {'Title': 'Apple Watch Series 9 41mm GPS Starlight Case w Sport Band MR8T3LL/A 2023 Model', 'Price': '294.99', 'Country of Origin': 'USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Series-9-41mm-GPS-Starlight-Case-w-Sport-Band-MR8T3LL-A-2023-Model-/145400118156'}, {'Title': 'Apple Watch Ultra GPS & Cellular 49mm Titanium Trail Alpine Loop Ocean Excellent', 'Price': '489.99', 'Country of Origin': 'Addison,TX,USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Ultra-GPS-Cellular-49mm-Titanium-Trail-Alpine-Loop-Ocean-Excellent-/165868496837?var=0'}, {'Title': 'Apple Watch SE 2nd Gen 40mm GPS Starlight Case & Band S/M MR9U3LL/A 2023 Model', 'Price': '179.99', 'Country of Origin': 'USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-SE-2nd-Gen-40mm-GPS-Starlight-Case-Band-S-M-MR9U3LL-A-2023-Model-/134795957975'}, {'Title': 'Apple Watch Series 4 40mm (GPS + Cellular) Aluminum Case - Used', 'Price': '99.99', 'Country of Origin': 'Astoria,NY,USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Series-4-40mm-GPS-Cellular-Aluminum-Case-Used-/255625315921?var=0'}, {'Title': 'Apple Watch Series 9 - GPS + GSM Cellular 41mm Smart Watch - Excellent', 'Price': '299.99', 'Country of Origin': 'Addison,TX,USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Series-9-GPS-GSM-Cellular-41mm-Smart-Watch-Excellent-/186156628205?var=694196222446'}, {'Title': 'Apple Watch Series 7 45mm GPS + WiFi + Cellular Unlocked Aluminum Case - Good', 'Price': '201.99', 'Country of Origin': 'Inglewood,CA,USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Series-7-45mm-GPS-WiFi-Cellular-Unlocked-Aluminum-Case-Good-/404057662889?var=673939059081'}, {'Title': 'Apple Watch Series 7 41mm GPS + WiFi + Cellular Unlocked Aluminum Case - Good', 'Price': '191.99', 'Country of Origin': 'Inglewood,CA,USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Series-7-41mm-GPS-WiFi-Cellular-Unlocked-Aluminum-Case-Good-/404057662041?var=673939010313'}, {'Title': 'Apple Watch Series 7 41mm 45mm GPS + WiFi + Cellular Blue Black Green Starlight', 'Price': '189.99', 'Country of Origin': 'Inglewood,CA,USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Series-7-41mm-45mm-GPS-WiFi-Cellular-Blue-Black-Green-Starlight-/314208138435?var=0'}, {'Title': 'Apple Watch Series SE (2nd Gen) GPS +Cellular 40mm Smart Watch - Excellent', 'Price': '174.99', 'Country of Origin': 'Addison,TX,USA', 'Product Link': 'https://www.ebay.com/itm/Apple-Watch-Series-SE-2nd-Gen-GPS-Cellular-40mm-Smart-Watch-Excellent-/185663844107?var=0'}, {'Title': 'Apple Watch Ultra 2 2nd Generati ...
# Apple Watch data saved to apple_watch_data13.xlsx

# %%
from ebaysdk.finding import Connection as Finding
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import os
import pandas as pd

load_dotenv()

# eBay API endpoint
EBAY_API_URL = "https://api.ebay.com/buy/browse/v1/item_summary/search"

# Get OAuth token from environment variable
OAUTH_TOKEN = os.getenv("EBAY_OAUTH_TOKEN")

# Function to fetch eBay data for Apple Watches
def fetch_ebay_data(query: str, limit: int = 100):
    api = Finding(appid="MosesMac-pricemon-PRD-85bb4ae7d-e6d9b5f3", config_file=None)
    response = api.execute('findItemsAdvanced', {'keywords': query, 'paginationInput': {'entriesPerPage': limit}})
    soup = BeautifulSoup(response.content, 'lxml')
    items = soup.find_all('item')
    relevant_data = []
    for item in items:
        item_info = {
            "Title": item.title.string,
            "Price": item.currentprice.string,
            "Country of Origin": item.location.string,
            "Product Link": item.viewitemurl.string
        }
        relevant_data.append(item_info)
    return relevant_data 

# Function to arrange price in ascending order
def arrange_price_ascending(data):
    data = sorted(data, key=lambda x: float(x["Price"].replace("$", "").replace(",", "")))
    return data

# Print the data
data = fetch_ebay_data("apple watch", 100)
sorted_data = arrange_price_ascending(data)
for i, item in enumerate(sorted_data[:10], start=1):
    print(f"{i}. Title: {item['Title']}")
    print(f"   Price: {item['Price']}")
    print(f"   Country of Origin: {item['Country of Origin']}")
    print(f"   Product Link: {item['Product Link']}")
    print()

# Save the data to Excel file
def save_to_excel(data, filename):
    df = pd.DataFrame(data)
    df.to_excel(filename, index=False)
    print(f"Apple Watch data saved to {filename}")

# Save the data to Excel file
save_to_excel(sorted_data, "apple_watch_data14.xlsx")
# Out:
# 1. Title: Apple Watch Series 3 38mm 42mm ALL COLORS Aluminum Case With Band GPS Cellular
#    Price: 79.99
#    Country of Origin: Lakewood,NJ,USA
#    Product Link: https://www.ebay.com/itm/Apple-Watch-Series-3-38mm-42mm-ALL-COLORS-Aluminum-Case-Band-GPS-Cellular-/125662941144?var=0
#
# 2. Title: Apple Watch Series 3 38mm / 42mm GPS WiFi + LTE Cellular - Good
#    Price: 84.55
#    Country of Origin: Crown Point,IN,USA
#    Product Link: https://www.ebay.com/itm/Apple-Watch-Series-3-38mm-42mm-GPS-WiFi-LTE-Cellular-Good-/355214711630?var=0
#
# 3. Title: Apple Watch Series 3 38mm 42mm GPS + WiFi + Cellular Pink Gold Space Gray Silver
#    Price: 89.99
#    Country of Origin: Inglewood,CA,USA
#    Product Link: https://www.ebay.com/itm/Apple-Watch-Series-3-38mm-42mm-GPS-WiFi-Cellular-Pink-Gold-Space-Gray-Silver-/194935793906?var=0
#
# 4. Title: Apple Watch Series 9 45mm Aluminum Case w/ Sport Band - Midnight, M/L (GPS+Cell)
#    Price: 98.08
#    Country of Origin: Columbus,OH,USA
#    Product Link: https://www.ebay.com/itm/Apple-Watch-Series-9-45mm-Aluminum-Case-w-Sport-Band-Midnight-M-L-GPS-Cell-/276325532398
#
# 5. Title: Apple Watch Series 4 40mm (GPS + Cellular) Aluminum Case - Used
#    Price: 99.99
#    Country of Origin: Astoria,NY,USA
#    Product Link: https://www.ebay.com/itm/Apple-Watch-Series-4-40mm-GPS-Cellular-Aluminum-Case-Used-/255625315921?var=0
#
# 6. Title: Apple Watch Series 4 40mm / 44mm GPS WiFi + LTE Cellular - Good
#    Price: 105.0
#    Country of Origin: Crown Point,IN,USA
#    Product Link: https://www.ebay.com/itm/Apple-Watch-Series-4-40mm-44mm-GPS-WiFi-LTE-Cellular-Good-/355214725943?var=0
#
# 7. Title: Apple Watch Series 5 40mm 44mm ALL COLORS Aluminum Case With Band GPS + Cellular
#    Price: 123.99
#    Country of Origin: Lakewood,NJ,USA
#    Product Link: https://www.ebay.com/itm/Apple-Watch-Series-5-40mm-44mm-ALL-COLORS-Aluminum-Case-Band-GPS-Cellular-/126268225885?var=0
#
# 8. Title: Apple Watch Series 4 40mm 44mm GPS + WiFi + Bluetooth Gold Gray Silver - Good
#    Price: 124.99
#    Country of Origin: Inglewood,CA,USA
#    Product Link: https://www.ebay.com/itm/Apple-Watch-Series-4-40mm-44mm-GPS-WiFi-Bluetooth-Gold-Gray-Silver-Good-/404026180086?var=0
#
# 9. Title: Apple Watch Series 5 (GPS + Cellular) 40mm Smartwatch - Good
#    Price: 124.99
#    Country of Origin: Astoria,NY,USA
#    Product Link: https://www.ebay.com/itm/Apple-Watch-Series-5-GPS-Cellular-40mm-Smartwatch-Good-/254993930996?var=0
#
# 10. Title: Apple Watch Series 5 44 mm Space Gray Aluminum Case with Black Loop GPS
#    Price: 124.99
#    Country of Origin: Portland,OR,USA
#    Product Link: https://www.ebay.com/itm/Apple-Watch-Series-5-44-mm-Space-Gray-Aluminum-Case-Black-Loop-GPS-/133684947930
#
# Apple Watch data saved to apple_watch_data14.xlsx

# %%
from ebaysdk.finding import Connection as Finding
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import os
import pandas as pd

load_dotenv()

# eBay API endpoint
EBAY_API_URL = "https://api.ebay.com/buy/browse/v1/item_summary/search"

# Get OAuth token from environment variable
OAUTH_TOKEN = os.getenv("EBAY_OAUTH_TOKEN")

# Function to fetch eBay data for Apple Watches
def fetch_ebay_data(query: str, limit: int = 100):
    api = Finding(appid="MosesMac-pricemon-PRD-85bb4ae7d-e6d9b5f3", config_file=None)
    response = api.execute('findItemsAdvanced', {'keywords': query, 'paginationInput': {'entriesPerPage': limit}})
    soup = BeautifulSoup(response.content, 'lxml')
    items = soup.find_all('item')
    relevant_data = []
    for item in items:
        item_info = {
            "Title": item.title.string,
            "Price": item.currentprice.string,
            "Country of Origin": item.location.string,
            "Product Link": item.viewitemurl.string
        }
        relevant_data.append(item_info)
    return relevant_data 

# Function to arrange price in ascending order
def arrange_price_ascending(data):
    data = sorted(data, key=lambda x: float(x["Price"].replace("$", "").replace(",", "")))
    return data

# Save the data to CSV file
def save_to_csv(data, filename):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)
    print(f"eBay data saved to {filename}")

# Fetch eBay data
data = fetch_ebay_data("apple watch", 100)

# Arrange data by price in ascending order
sorted_data = arrange_price_ascending(data)

# Save the data to CSV file
save_to_csv(sorted_data, "apple_watch_data.csv")
# Out:
# eBay data saved to apple_watch_data.csv
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
from ebaysdk.finding import Connection as Finding
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import os
import pandas as pd

load_dotenv()

# eBay API endpoint
EBAY_API_URL = "https://api.ebay.com/buy/browse/v1/item_summary/search"

# Get OAuth token from environment variable
OAUTH_TOKEN = os.getenv("EBAY_OAUTH_TOKEN")

# Function to fetch eBay data for multiple watch brands
def fetch_ebay_data(queries: list, limit_per_query: int = 100):
    api = Finding(appid="MosesMac-pricemon-PRD-85bb4ae7d-e6d9b5f3", config_file=None)
    all_data = []
    for query in queries:
        response = api.execute('findItemsAdvanced', {'keywords': query, 'paginationInput': {'entriesPerPage': limit_per_query}})
        soup = BeautifulSoup(response.content, 'lxml')
        items = soup.find_all('item')
        relevant_data = []
        for item in items:
            item_info = {
                "Title": item.title.string,
                "Price": item.currentprice.string,
                "Country of Origin": item.location.string,
                "Product Link": item.viewitemurl.string
            }
            relevant_data.append(item_info)
        all_data.extend(relevant_data)
    return all_data

# Function to arrange price in ascending order
def arrange_price_ascending(data):
    data = sorted(data, key=lambda x: float(x["Price"].replace("$", "").replace(",", "")))
    return data

# Save the data to CSV file
def save_to_csv(data, filename):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)
    print(f"eBay data saved to {filename}")

# List of watch brands to search for
watch_brands = ["Rolex", "Omega", "Tag Heuer", "Seiko", "Casio"]

# Fetch eBay data for all watch brands
data = fetch_ebay_data(watch_brands, limit_per_query=100)

# Arrange data by price in ascending order
sorted_data = arrange_price_ascending(data)

# Save the data to CSV file
save_to_csv(sorted_data, "watch_data.csv")
# Out:
# eBay data saved to watch_data.csv

# %%
#load the data from the csv file
df = pd.read_csv("watch_data.csv")

# %%
#display the first 5 rows of the data
print(df.head())
# Out:
#                                                Title  Price Country of Origin  \
# 0  New TAG Heuer Formula 1 Blue Men's Watch - CAZ...   2.25           Ukraine
# 1   NOW Foods Omega-3 Fish Oil, 1000 mg, 30 Softgels   3.99    Lombard,IL,USA
# 2  Dial Omega Moisture Glycerin Bar Soap, Sea Ber...   6.05     Denver,CO,USA
# 3       Omega One Sinking Super Color Pellets 4.2 oz   7.59  Edinburgh,IN,USA
# 4  NOW Foods Omega-3 Fish OIl, 1000 mg, 100 Softgels   7.69    Lombard,IL,USA
#
#                                         Product Link
# 0  https://www.ebay.com/itm/New-TAG-Heuer-Formula...
# 1  https://www.ebay.com/itm/NOW-Foods-Omega-3-Fis...
# 2  https://www.ebay.com/itm/Dial-Omega-Moisture-G...
# 3  https://www.ebay.com/itm/Omega-One-Sinking-Sup...
# 4  https://www.ebay.com/itm/NOW-Foods-Omega-3-Fis...

# %%
from ebaysdk.finding import Connection as Finding
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import os
import pandas as pd

load_dotenv()

# eBay API endpoint
EBAY_API_URL = "https://api.ebay.com/buy/browse/v1/item_summary/search"

# Get OAuth token from environment variable
OAUTH_TOKEN = os.getenv("EBAY_OAUTH_TOKEN")

# Function to fetch eBay data for multiple watch brands
def fetch_ebay_data(keywords: list, limit_per_query: int = 100):
    api = Finding(appid="MosesMac-pricemon-PRD-85bb4ae7d-e6d9b5f3", config_file=None)
    all_data = []
    for keyword in keywords:
        response = api.execute('findItemsAdvanced', {
            'keywords': keyword,
            'paginationInput': {'entriesPerPage': limit_per_query},
            'categoryId': '14324'  # Category ID for watches
        })
        soup = BeautifulSoup(response.content, 'lxml')
        items = soup.find_all('item')
        relevant_data = []
        for item in items:
            item_info = {
                "Title": item.title.string,
                "Price": item.currentprice.string,
                "Country of Origin": item.location.string,
                "Product Link": item.viewitemurl.string
            }
            relevant_data.append(item_info)
        all_data.extend(relevant_data)
    return all_data

# Function to arrange price in ascending order
def arrange_price_ascending(data):
    data = sorted(data, key=lambda x: float(x["Price"].replace("$", "").replace(",", "")))
    return data

# Save the data to CSV file
def save_to_csv(data, filename):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)
    print(f"eBay data saved to {filename}")

# List of watch-related keywords to search for
watch_keywords = ["rolex", "apple", "hmt pilot", "invicta", "seiko", "quartz", 
                  "olevs", "citizen", "curren", "casio", "omega", "timex", "mechanical"]

# Fetch eBay data for watch-related keywords
data = fetch_ebay_data(watch_keywords, limit_per_query=100)

# Arrange data by price in ascending order
sorted_data = arrange_price_ascending(data)

# Save the data to CSV file
save_to_csv(sorted_data, "watch_data1.csv")
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# eBay data saved to watch_data1.csv

# %%
#display the first 5 rows of the data
print(df.head())
# Out:
#                                                Title  Price Country of Origin  \
# 0  New TAG Heuer Formula 1 Blue Men's Watch - CAZ...   2.25           Ukraine
# 1   NOW Foods Omega-3 Fish Oil, 1000 mg, 30 Softgels   3.99    Lombard,IL,USA
# 2  Dial Omega Moisture Glycerin Bar Soap, Sea Ber...   6.05     Denver,CO,USA
# 3       Omega One Sinking Super Color Pellets 4.2 oz   7.59  Edinburgh,IN,USA
# 4  NOW Foods Omega-3 Fish OIl, 1000 mg, 100 Softgels   7.69    Lombard,IL,USA
#
#                                         Product Link
# 0  https://www.ebay.com/itm/New-TAG-Heuer-Formula...
# 1  https://www.ebay.com/itm/NOW-Foods-Omega-3-Fis...
# 2  https://www.ebay.com/itm/Dial-Omega-Moisture-G...
# 3  https://www.ebay.com/itm/Omega-One-Sinking-Sup...
# 4  https://www.ebay.com/itm/NOW-Foods-Omega-3-Fis...

# %%
#first 10 rows of the data
print(df.head(10))
# Out:
#                                                Title  Price  \
# 0  New TAG Heuer Formula 1 Blue Men's Watch - CAZ...   2.25
# 1   NOW Foods Omega-3 Fish Oil, 1000 mg, 30 Softgels   3.99
# 2  Dial Omega Moisture Glycerin Bar Soap, Sea Ber...   6.05
# 3       Omega One Sinking Super Color Pellets 4.2 oz   7.59
# 4  NOW Foods Omega-3 Fish OIl, 1000 mg, 100 Softgels   7.69
# 5  Antarctic Krill oil 2000mg - with Omega-3 EPA,...   7.71
# 6  Antarctic Krill Oil 1000mg -with Omega-3 EPA, ...   7.80
# 7  SONY PLAYSTATION 2 PS2 GAMES LOT YOU PICK BUY ...   7.98
# 8  Omega-3 Fish Oil from Alaska Deep Sea, 1000mg,...   7.99
# 9  NOW Foods Molecularly Distilled Omega-3 1,000 ...   8.14
#
#          Country of Origin                                       Product Link
# 0                  Ukraine  https://www.ebay.com/itm/New-TAG-Heuer-Formula...
# 1           Lombard,IL,USA  https://www.ebay.com/itm/NOW-Foods-Omega-3-Fis...
# 2            Denver,CO,USA  https://www.ebay.com/itm/Dial-Omega-Moisture-G...
# 3         Edinburgh,IN,USA  https://www.ebay.com/itm/Omega-One-Sinking-Sup...
# 4           Lombard,IL,USA  https://www.ebay.com/itm/NOW-Foods-Omega-3-Fis...
# 5                    China  https://www.ebay.com/itm/Antarctic-Krill-oil-2...
# 6                    China  https://www.ebay.com/itm/Antarctic-Krill-Oil-1...
# 7  Port Saint Lucie,FL,USA  https://www.ebay.com/itm/SONY-PLAYSTATION-2-PS...
# 8            Walnut,CA,USA  https://www.ebay.com/itm/Omega-3-Fish-Oil-Alas...
# 9             Fargo,ND,USA  https://www.ebay.com/itm/NOW-Foods-Molecularly...
